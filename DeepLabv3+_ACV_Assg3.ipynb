# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehsan1997/ImageSegmentation-UNET-DeepLab-SegNet/blob/master/DeepLabv3%2B_ACV_Assg3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://drive.google.com/uc?id=1K4APdA6GUhS57kS6YGMYIU8QhFMHSDLd
# !unzip -q ModMonuSeg.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K4APdA6GUhS57kS6YGMYIU8QhFMHSDLd
# To: /content/ModMonuSeg.zip
# 224MB [00:01, 164MB/s]

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from tensorflow.keras.layers import Lambda, RepeatVector, Reshape, Add, Concatenate, ZeroPadding2D
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, DepthwiseConv2D
from tensorflow.keras.layers import MaxPooling2D, GlobalMaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.layers import concatenate, add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.python.keras.activations import relu

from tensorflow.keras import backend as K

# %%
# Set some parameters
im_width = 256
im_height = 256

# %% [markdown]
# #### Load the images and masks into arrays

# %%
def get_images(parent_dir, im_shape, img_folder="TissueImages/", gt_folder="GroundTruth/", gt_extension=None):
  tissue_dir = parent_dir + img_folder
  gt_dir = parent_dir + gt_folder

  im_width, im_height = im_shape


  ids = next(os.walk(tissue_dir))[2]
  print("No. of images = ", len(ids))

  X = np.zeros((len(ids), im_height, im_width, 3), dtype=np.float32)
  y = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)

  # tqdm is used to display the progress bar
  for n, id_ in tqdm_notebook(enumerate(ids), total=len(ids)):
    # Load images
    img = load_img(tissue_dir+id_)
    x_img = img_to_array(img)
    x_img = resize(x_img, (im_width, im_height, 3), mode = 'constant', preserve_range = True)
    # Load masks
    mask_id_ = id_.split('.')[0]
    mask_id_ = '-'.join(id_.split('-')[:-1]) + '_bin_mask-'+ id_.split('-')[-1]
    if gt_extension:
      mask_id_ = mask_id_.split('.')[0] + '.' + gt_extension
    mask = img_to_array(load_img(gt_dir+mask_id_, grayscale=True))
    mask = resize(mask, (im_width, im_height, 1), mode = 'constant', preserve_range = True)
    # Save images
    X[n] = x_img/255.0
    y[n] = mask/255.0

  return X, y

# %%
# Split train and valid
X, y = get_images("ModMonuSeg/Training/", (im_width, im_height))
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)
# Out:
# No. of images =  1080
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(IntProgress(value=0, max=1080), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %% [markdown]
# #### Below code can be used to visualize the images and corresponding masks

# %%
# Visualize any randome image along with the mask
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0 # salt indicator

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 15))

ax1.imshow(X_train[ix, ..., 0], cmap = 'seismic', interpolation = 'bilinear')
if has_mask: # if salt
    # draw a boundary(contour) in the original image separating salt and non-salt areas
    ax1.contour(y_train[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5])
ax1.set_title('TissueImage')

ax2.imshow(y_train[ix].squeeze(), cmap = 'gray', interpolation = 'bilinear')
ax2.set_title('GroundTruth')
# Out:
# Text(0.5, 1.0, 'GroundTruth')

# %%
# Define Some metrics
## Dice Score
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())
## F1 Score
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
WEIGHTS_PATH_X = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_MOBILE = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.1/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5"
WEIGHTS_PATH_X_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5"
WEIGHTS_PATH_MOBILE_CS = "https://github.com/bonlime/keras-deeplab-v3-plus/releases/download/1.2/deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5"


def SepConv_BN(x, filters, prefix, stride=1, kernel_size=3, rate=1, depth_activation=False, epsilon=1e-3):
    """ SepConv with BN between depthwise & pointwise. Optionally add activation after BN
        Implements right "same" padding for even kernel sizes
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & poinwise convs
            epsilon: epsilon to use in BN layer
    """

    if stride == 1:
        depth_padding = 'same'
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        depth_padding = 'valid'

    if not depth_activation:
        x = Activation('relu')(x)
    x = DepthwiseConv2D((kernel_size, kernel_size), strides=(stride, stride), dilation_rate=(rate, rate),
                        padding=depth_padding, use_bias=False, name=prefix + '_depthwise')(x)
    x = BatchNormalization(name=prefix + '_depthwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)
    x = Conv2D(filters, (1, 1), padding='same',
               use_bias=False, name=prefix + '_pointwise')(x)
    x = BatchNormalization(name=prefix + '_pointwise_BN', epsilon=epsilon)(x)
    if depth_activation:
        x = Activation('relu')(x)

    return x


def _conv2d_same(x, filters, prefix, stride=1, kernel_size=3, rate=1):
    """Implements right 'same' padding for even kernel sizes
        Without this there is a 1 pixel drift when stride = 2
        Args:
            x: input tensor
            filters: num of filters in pointwise convolution
            prefix: prefix before name
            stride: stride at depthwise conv
            kernel_size: kernel size for depthwise convolution
            rate: atrous rate for depthwise convolution
    """
    if stride == 1:
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='same', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)
    else:
        kernel_size_effective = kernel_size + (kernel_size - 1) * (rate - 1)
        pad_total = kernel_size_effective - 1
        pad_beg = pad_total // 2
        pad_end = pad_total - pad_beg
        x = ZeroPadding2D((pad_beg, pad_end))(x)
        return Conv2D(filters,
                      (kernel_size, kernel_size),
                      strides=(stride, stride),
                      padding='valid', use_bias=False,
                      dilation_rate=(rate, rate),
                      name=prefix)(x)


def _xception_block(inputs, depth_list, prefix, skip_connection_type, stride,
                    rate=1, depth_activation=False, return_skip=False):
    """ Basic building block of modified Xception network
        Args:
            inputs: input tensor
            depth_list: number of filters in each SepConv layer. len(depth_list) == 3
            prefix: prefix before name
            skip_connection_type: one of {'conv','sum','none'}
            stride: stride at last depthwise conv
            rate: atrous rate for depthwise convolution
            depth_activation: flag to use activation between depthwise & pointwise convs
            return_skip: flag to return additional tensor after 2 SepConvs for decoder
            """
    residual = inputs
    for i in range(3):
        residual = SepConv_BN(residual,
                              depth_list[i],
                              prefix + '_separable_conv{}'.format(i + 1),
                              stride=stride if i == 2 else 1,
                              rate=rate,
                              depth_activation=depth_activation)
        if i == 1:
            skip = residual
    if skip_connection_type == 'conv':
        shortcut = _conv2d_same(inputs, depth_list[-1], prefix + '_shortcut',
                                kernel_size=1,
                                stride=stride)
        shortcut = BatchNormalization(name=prefix + '_shortcut_BN')(shortcut)
        outputs = tf.keras.layers.add([residual, shortcut])
    elif skip_connection_type == 'sum':
        outputs = tf.keras.layers.add([residual, inputs])
    elif skip_connection_type == 'none':
        outputs = residual
    if return_skip:
        return outputs, skip
    else:
        return outputs


def relu6(x):
    return relu(x, max_value=6)


def _make_divisible(v, divisor, min_value=None):
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


def _inverted_res_block(inputs, expansion, stride, alpha, filters, block_id, skip_connection, rate=1):
    in_channels = inputs.shape[-1]  # inputs._keras_shape[-1]
    pointwise_conv_filters = int(filters * alpha)
    pointwise_filters = _make_divisible(pointwise_conv_filters, 8)
    x = inputs
    prefix = 'expanded_conv_{}_'.format(block_id)
    if block_id:
        # Expand

        x = Conv2D(expansion * in_channels, kernel_size=1, padding='same',
                   use_bias=False, activation=None,
                   name=prefix + 'expand')(x)
        x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                               name=prefix + 'expand_BN')(x)
        x = Activation(relu6, name=prefix + 'expand_relu')(x)
    else:
        prefix = 'expanded_conv_'
    # Depthwise
    x = DepthwiseConv2D(kernel_size=3, strides=stride, activation=None,
                        use_bias=False, padding='same', dilation_rate=(rate, rate),
                        name=prefix + 'depthwise')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'depthwise_BN')(x)

    x = Activation(relu6, name=prefix + 'depthwise_relu')(x)

    # Project
    x = Conv2D(pointwise_filters,
               kernel_size=1, padding='same', use_bias=False, activation=None,
               name=prefix + 'project')(x)
    x = BatchNormalization(epsilon=1e-3, momentum=0.999,
                           name=prefix + 'project_BN')(x)

    if skip_connection:
        return Add(name=prefix + 'add')([inputs, x])

    # if in_channels == pointwise_filters and stride == 1:
    #    return Add(name='res_connect_' + str(block_id))([inputs, x])

    return x


def Deeplabv3(weights='pascal_voc', input_tensor=None, input_shape=(512, 512, 3), classes=21, backbone='mobilenetv2',
              OS=16, alpha=1., activation=None):
    """ Instantiates the Deeplabv3+ architecture
    Optionally loads weights pre-trained
    on PASCAL VOC or Cityscapes. This model is available for TensorFlow only.
    # Arguments
        weights: one of 'pascal_voc' (pre-trained on pascal voc),
            'cityscapes' (pre-trained on cityscape) or None (random initialization)
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: shape of input image. format HxWxC
            PASCAL VOC model was trained on (512,512,3) images. None is allowed as shape/width
        classes: number of desired classes. PASCAL VOC has 21 classes, Cityscapes has 19 classes.
            If number of classes not aligned with the weights used, last layer is initialized randomly
        backbone: backbone to use. one of {'xception','mobilenetv2'}
        activation: optional activation to add to the top of the network.
            One of 'softmax', 'sigmoid' or None
        OS: determines input_shape/feature_extractor_output ratio. One of {8,16}.
            Used only for xception backbone.
        alpha: controls the width of the MobileNetV2 network. This is known as the
            width multiplier in the MobileNetV2 paper.
                - If `alpha` < 1.0, proportionally decreases the number
                    of filters in each layer.
                - If `alpha` > 1.0, proportionally increases the number
                    of filters in each layer.
                - If `alpha` = 1, default number of filters from the paper
                    are used at each layer.
            Used only for mobilenetv2 backbone. Pretrained is only available for alpha=1.
    # Returns
        A Keras model instance.
    # Raises
        RuntimeError: If attempting to run this model with a
            backend that does not support separable convolutions.
        ValueError: in case of invalid argument for `weights` or `backbone`
    """

    if not (weights in {'pascal_voc', 'cityscapes', None}):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `pascal_voc`, or `cityscapes` '
                         '(pre-trained on PASCAL VOC)')

    if not (backbone in {'xception', 'mobilenetv2'}):
        raise ValueError('The `backbone` argument should be either '
                         '`xception`  or `mobilenetv2` ')

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        img_input = input_tensor

    if backbone == 'xception':
        if OS == 8:
            entry_block3_stride = 1
            middle_block_rate = 2  # ! Not mentioned in paper, but required
            exit_block_rates = (2, 4)
            atrous_rates = (12, 24, 36)
        else:
            entry_block3_stride = 2
            middle_block_rate = 1
            exit_block_rates = (1, 2)
            atrous_rates = (6, 12, 18)

        x = Conv2D(32, (3, 3), strides=(2, 2),
                   name='entry_flow_conv1_1', use_bias=False, padding='same')(img_input)
        x = BatchNormalization(name='entry_flow_conv1_1_BN')(x)
        x = Activation('relu')(x)

        x = _conv2d_same(x, 64, 'entry_flow_conv1_2', kernel_size=3, stride=1)
        x = BatchNormalization(name='entry_flow_conv1_2_BN')(x)
        x = Activation('relu')(x)

        x = _xception_block(x, [128, 128, 128], 'entry_flow_block1',
                            skip_connection_type='conv', stride=2,
                            depth_activation=False)
        x, skip1 = _xception_block(x, [256, 256, 256], 'entry_flow_block2',
                                   skip_connection_type='conv', stride=2,
                                   depth_activation=False, return_skip=True)

        x = _xception_block(x, [728, 728, 728], 'entry_flow_block3',
                            skip_connection_type='conv', stride=entry_block3_stride,
                            depth_activation=False)
        for i in range(16):
            x = _xception_block(x, [728, 728, 728], 'middle_flow_unit_{}'.format(i + 1),
                                skip_connection_type='sum', stride=1, rate=middle_block_rate,
                                depth_activation=False)

        x = _xception_block(x, [728, 1024, 1024], 'exit_flow_block1',
                            skip_connection_type='conv', stride=1, rate=exit_block_rates[0],
                            depth_activation=False)
        x = _xception_block(x, [1536, 1536, 2048], 'exit_flow_block2',
                            skip_connection_type='none', stride=1, rate=exit_block_rates[1],
                            depth_activation=True)

    else:
        OS = 8
        first_block_filters = _make_divisible(32 * alpha, 8)
        x = Conv2D(first_block_filters,
                   kernel_size=3,
                   strides=(2, 2), padding='same',
                   use_bias=False, name='Conv')(img_input)
        x = BatchNormalization(
            epsilon=1e-3, momentum=0.999, name='Conv_BN')(x)
        x = Activation(relu6, name='Conv_Relu6')(x)

        x = _inverted_res_block(x, filters=16, alpha=alpha, stride=1,
                                expansion=1, block_id=0, skip_connection=False)

        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=2,
                                expansion=6, block_id=1, skip_connection=False)
        x = _inverted_res_block(x, filters=24, alpha=alpha, stride=1,
                                expansion=6, block_id=2, skip_connection=True)

        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=2,
                                expansion=6, block_id=3, skip_connection=False)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=4, skip_connection=True)
        x = _inverted_res_block(x, filters=32, alpha=alpha, stride=1,
                                expansion=6, block_id=5, skip_connection=True)

        # stride in block 6 changed from 2 -> 1, so we need to use rate = 2
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1,  # 1!
                                expansion=6, block_id=6, skip_connection=False)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=7, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=8, skip_connection=True)
        x = _inverted_res_block(x, filters=64, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=9, skip_connection=True)

        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=10, skip_connection=False)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=11, skip_connection=True)
        x = _inverted_res_block(x, filters=96, alpha=alpha, stride=1, rate=2,
                                expansion=6, block_id=12, skip_connection=True)

        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=2,  # 1!
                                expansion=6, block_id=13, skip_connection=False)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=14, skip_connection=True)
        x = _inverted_res_block(x, filters=160, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=15, skip_connection=True)

        x = _inverted_res_block(x, filters=320, alpha=alpha, stride=1, rate=4,
                                expansion=6, block_id=16, skip_connection=False)

    # end of feature extractor

    # branching for Atrous Spatial Pyramid Pooling

    # Image Feature branch
    shape_before = tf.shape(x)
    b4 = GlobalAveragePooling2D()(x)
    # from (b_size, channels)->(b_size, 1, 1, channels)
    b4 = Lambda(lambda x: K.expand_dims(x, 1))(b4)
    b4 = Lambda(lambda x: K.expand_dims(x, 1))(b4)
    b4 = Conv2D(256, (1, 1), padding='same',
                use_bias=False, name='image_pooling')(b4)
    b4 = BatchNormalization(name='image_pooling_BN', epsilon=1e-5)(b4)
    b4 = Activation('relu')(b4)
    # upsample. have to use compat because of the option align_corners
    size_before = tf.keras.backend.int_shape(x)
    b4 = Lambda(lambda x: tf.compat.v1.image.resize(x, size_before[1:3],
                                                    method='bilinear', align_corners=True))(b4)
    # simple 1x1
    b0 = Conv2D(256, (1, 1), padding='same', use_bias=False, name='aspp0')(x)
    b0 = BatchNormalization(name='aspp0_BN', epsilon=1e-5)(b0)
    b0 = Activation('relu', name='aspp0_activation')(b0)

    # there are only 2 branches in mobilenetV2. not sure why
    if backbone == 'xception':
        # rate = 6 (12)
        b1 = SepConv_BN(x, 256, 'aspp1',
                        rate=atrous_rates[0], depth_activation=True, epsilon=1e-5)
        # rate = 12 (24)
        b2 = SepConv_BN(x, 256, 'aspp2',
                        rate=atrous_rates[1], depth_activation=True, epsilon=1e-5)
        # rate = 18 (36)
        b3 = SepConv_BN(x, 256, 'aspp3',
                        rate=atrous_rates[2], depth_activation=True, epsilon=1e-5)

        # concatenate ASPP branches & project
        x = Concatenate()([b4, b0, b1, b2, b3])
    else:
        x = Concatenate()([b4, b0])

    x = Conv2D(256, (1, 1), padding='same',
               use_bias=False, name='concat_projection')(x)
    x = BatchNormalization(name='concat_projection_BN', epsilon=1e-5)(x)
    x = Activation('relu')(x)
    x = Dropout(0.1)(x)
    # DeepLab v.3+ decoder

    if backbone == 'xception':
        # Feature projection
        # x4 (x2) block
        size_before2 = tf.keras.backend.int_shape(x)
        x = Lambda(lambda xx: tf.compat.v1.image.resize(xx,
                                                        size_before2[1:3] * tf.constant(OS // 4),
                                                        method='bilinear', align_corners=True))(x)

        dec_skip1 = Conv2D(48, (1, 1), padding='same',
                           use_bias=False, name='feature_projection0')(skip1)
        dec_skip1 = BatchNormalization(
            name='feature_projection0_BN', epsilon=1e-5)(dec_skip1)
        dec_skip1 = Activation('relu')(dec_skip1)
        x = Concatenate()([x, dec_skip1])
        x = SepConv_BN(x, 256, 'decoder_conv0',
                       depth_activation=True, epsilon=1e-5)
        x = SepConv_BN(x, 256, 'decoder_conv1',
                       depth_activation=True, epsilon=1e-5)

    # you can use it with arbitary number of classes
    if (weights == 'pascal_voc' and classes == 21) or (weights == 'cityscapes' and classes == 19):
        last_layer_name = 'logits_semantic'
    else:
        last_layer_name = 'custom_logits_semantic'

    x = Conv2D(classes, (1, 1), padding='same', name=last_layer_name)(x)
    size_before3 = tf.keras.backend.int_shape(img_input)
    x = Lambda(lambda xx: tf.compat.v1.image.resize(xx,
                                                    size_before3[1:3],
                                                    method='bilinear', align_corners=True))(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    if activation in {'softmax', 'sigmoid'}:
        x = tf.keras.layers.Activation(activation)(x)

    model = Model(inputs, x, name='deeplabv3plus')

    # load weights

    if weights == 'pascal_voc':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_X,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels.h5',
                                    WEIGHTS_PATH_MOBILE,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    elif weights == 'cityscapes':
        if backbone == 'xception':
            weights_path = get_file('deeplabv3_xception_tf_dim_ordering_tf_kernels_cityscapes.h5',
                                    WEIGHTS_PATH_X_CS,
                                    cache_subdir='models')
        else:
            weights_path = get_file('deeplabv3_mobilenetv2_tf_dim_ordering_tf_kernels_cityscapes.h5',
                                    WEIGHTS_PATH_MOBILE_CS,
                                    cache_subdir='models')
        model.load_weights(weights_path, by_name=True)
    return model

def preprocess_input(x):
    """Preprocesses a numpy array encoding a batch of images.
    # Arguments
        x: a 4D numpy array consists of RGB values within [0, 255].
    # Returns
        Input array scaled to [-1.,1.]
    """
    return preprocess_input(x, mode='tf')

# %%
model = Deeplabv3(weights=None, input_tensor=None, input_shape=(256, 256, 3), classes=1, backbone='xception',
              OS=16, alpha=1., activation='sigmoid')
model.summary()
# Out:
# Model: "deeplabv3plus"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# entry_flow_conv1_1 (Conv2D)     (None, 128, 128, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_1_BN (BatchNor (None, 128, 128, 32) 128         entry_flow_conv1_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 128, 32) 0           entry_flow_conv1_1_BN[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2 (Conv2D)     (None, 128, 128, 64) 18432       activation[0][0]
# __________________________________________________________________________________________________
# entry_flow_conv1_2_BN (BatchNor (None, 128, 128, 64) 256         entry_flow_conv1_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 64) 0           entry_flow_conv1_2_BN[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 64) 576         activation_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 64) 256         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 8192        entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           entry_flow_block1_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 1152        activation_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 16384       entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 128, 128, 128 512         entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 130, 130, 128 0           entry_flow_block1_separable_conv2
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 130, 130, 128 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 64, 64, 128)  1152        activation_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 64, 64, 128)  512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 64, 64, 128)  16384       entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut (Con (None, 64, 64, 128)  8192        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block1_separable_con (None, 64, 64, 128)  512         entry_flow_block1_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block1_shortcut_BN ( (None, 64, 64, 128)  512         entry_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 128)  0           entry_flow_block1_separable_conv3
#                                                                  entry_flow_block1_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 128)  1152        activation_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 128)  512         entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  32768       entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           entry_flow_block2_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  2304        activation_6[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  65536       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 64, 64, 256)  1024        entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 66, 66, 256)  0           entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 66, 66, 256)  0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 32, 32, 256)  2304        activation_7[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 32, 32, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 64, 64, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 32, 32, 256)  65536       entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut (Con (None, 32, 32, 256)  32768       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# entry_flow_block2_separable_con (None, 32, 32, 256)  1024        entry_flow_block2_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block2_shortcut_BN ( (None, 32, 32, 256)  1024        entry_flow_block2_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           entry_flow_block2_separable_conv3
#                                                                  entry_flow_block2_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 256)  2304        activation_8[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 256)  1024        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  186368      entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 728)  0           entry_flow_block3_separable_conv1
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  6552        activation_9[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  529984      entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 32, 32, 728)  2912        entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 34, 34, 728)  0           entry_flow_block3_separable_conv2
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 34, 34, 728)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 16, 16, 728)  6552        activation_10[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 16, 16, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 16, 16, 728)  529984      entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut (Con (None, 16, 16, 728)  186368      zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# entry_flow_block3_separable_con (None, 16, 16, 728)  2912        entry_flow_block3_separable_conv3
# __________________________________________________________________________________________________
# entry_flow_block3_shortcut_BN ( (None, 16, 16, 728)  2912        entry_flow_block3_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 728)  0           entry_flow_block3_separable_conv3
#                                                                  entry_flow_block3_shortcut_BN[0][
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  6552        activation_11[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  6552        activation_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  6552        activation_13[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_1_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_1_separable_conv
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_1_separable_conv
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  6552        activation_14[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  6552        activation_15[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  6552        activation_16[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_2_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_2_separable_conv
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_2_separable_conv
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  6552        activation_17[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  6552        activation_18[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  6552        activation_19[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_3_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_3_separable_conv
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_3_separable_conv
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  6552        activation_20[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  6552        activation_21[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  6552        activation_22[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_4_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_4_separable_conv
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_4_separable_conv
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  6552        activation_23[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  6552        activation_24[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  6552        activation_25[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_5_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_5_separable_conv
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_5_separable_conv
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  6552        activation_26[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  6552        activation_27[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  6552        activation_28[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_6_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_6_separable_conv
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_6_separable_conv
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  6552        activation_29[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  6552        activation_30[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  6552        activation_31[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_7_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_7_separable_conv
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 728)  0           middle_flow_unit_7_separable_conv
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  6552        activation_32[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  6552        activation_33[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  6552        activation_34[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_8_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_8_separable_conv
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 728)  0           middle_flow_unit_8_separable_conv
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  6552        activation_35[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  6552        activation_36[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  6552        activation_37[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  529984      middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# middle_flow_unit_9_separable_co (None, 16, 16, 728)  2912        middle_flow_unit_9_separable_conv
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 728)  0           middle_flow_unit_9_separable_conv
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 728)  0           add_11[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  6552        activation_38[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  6552        activation_39[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  6552        activation_40[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  529984      middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_10_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_10_separable_con
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 728)  0           middle_flow_unit_10_separable_con
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 728)  0           add_12[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 16, 16, 728)  6552        activation_41[0][0]
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 16, 16, 728)  529984      middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 16, 16, 728)  2912        middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 728)  0           middle_flow_unit_11_separable_con
# __________________________________________________________________________________________________
# middle_flow_unit_11_separable_c (None, 16, 16, 728)  6552        activation_42[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 16, 16, 1024) 1048576     exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut (Conv (None, 16, 16, 1024) 745472      add_18[0][0]
# __________________________________________________________________________________________________
# exit_flow_block1_separable_conv (None, 16, 16, 1024) 4096        exit_flow_block1_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block1_shortcut_BN (B (None, 16, 16, 1024) 4096        exit_flow_block1_shortcut[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 16, 16, 1024) 0           exit_flow_block1_separable_conv3_
#                                                                  exit_flow_block1_shortcut_BN[0][0
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1024) 9216        add_19[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1024) 4096        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 16, 16, 1024) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 1572864     activation_62[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 6144        exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 16, 16, 1536) 0           exit_flow_block2_separable_conv1_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 13824       activation_63[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 16, 16, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 2359296     activation_64[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 6144        exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 16, 16, 1536) 0           exit_flow_block2_separable_conv2_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 13824       activation_65[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 1536) 6144        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 16, 1536) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 2048) 3145728     activation_66[0][0]
# __________________________________________________________________________________________________
# exit_flow_block2_separable_conv (None, 16, 16, 2048) 8192        exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 2048) 0           exit_flow_block2_separable_conv3_
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           activation_67[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1, 2048)      0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise (DepthwiseConv2 (None, 16, 16, 2048) 18432       activation_67[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise (DepthwiseConv2 (None, 16, 16, 2048) 18432       activation_67[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise (DepthwiseConv2 (None, 16, 16, 2048) 18432       activation_67[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 1, 2048)   0           lambda[0][0]
# __________________________________________________________________________________________________
# aspp1_depthwise_BN (BatchNormal (None, 16, 16, 2048) 8192        aspp1_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp2_depthwise_BN (BatchNormal (None, 16, 16, 2048) 8192        aspp2_depthwise[0][0]
# __________________________________________________________________________________________________
# aspp3_depthwise_BN (BatchNormal (None, 16, 16, 2048) 8192        aspp3_depthwise[0][0]
# __________________________________________________________________________________________________
# image_pooling (Conv2D)          (None, 1, 1, 256)    524288      lambda_1[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 2048) 0           aspp1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 16, 16, 2048) 0           aspp2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 16, 16, 2048) 0           aspp3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# image_pooling_BN (BatchNormaliz (None, 1, 1, 256)    1024        image_pooling[0][0]
# __________________________________________________________________________________________________
# aspp0 (Conv2D)                  (None, 16, 16, 256)  524288      activation_67[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise (Conv2D)        (None, 16, 16, 256)  524288      activation_69[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise (Conv2D)        (None, 16, 16, 256)  524288      activation_71[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise (Conv2D)        (None, 16, 16, 256)  524288      activation_73[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 1, 1, 256)    0           image_pooling_BN[0][0]
# __________________________________________________________________________________________________
# aspp0_BN (BatchNormalization)   (None, 16, 16, 256)  1024        aspp0[0][0]
# __________________________________________________________________________________________________
# aspp1_pointwise_BN (BatchNormal (None, 16, 16, 256)  1024        aspp1_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp2_pointwise_BN (BatchNormal (None, 16, 16, 256)  1024        aspp2_pointwise[0][0]
# __________________________________________________________________________________________________
# aspp3_pointwise_BN (BatchNormal (None, 16, 16, 256)  1024        aspp3_pointwise[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 256)  0           activation_68[0][0]
# __________________________________________________________________________________________________
# aspp0_activation (Activation)   (None, 16, 16, 256)  0           aspp0_BN[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 16, 256)  0           aspp1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 16, 16, 256)  0           aspp2_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 16, 256)  0           aspp3_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 1280) 0           lambda_2[0][0]
#                                                                  aspp0_activation[0][0]
#                                                                  activation_70[0][0]
#                                                                  activation_72[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# concat_projection (Conv2D)      (None, 16, 16, 256)  327680      concatenate[0][0]
# __________________________________________________________________________________________________
# concat_projection_BN (BatchNorm (None, 16, 16, 256)  1024        concat_projection[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 16, 256)  0           concat_projection_BN[0][0]
# __________________________________________________________________________________________________
# feature_projection0 (Conv2D)    (None, 64, 64, 48)   12288       entry_flow_block2_separable_conv2
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 256)  0           activation_75[0][0]
# __________________________________________________________________________________________________
# feature_projection0_BN (BatchNo (None, 64, 64, 48)   192         feature_projection0[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 256)  0           dropout[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 64, 64, 48)   0           feature_projection0_BN[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 304)  0           lambda_3[0][0]
#                                                                  activation_76[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise (Depthw (None, 64, 64, 304)  2736        concatenate_1[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_depthwise_BN (Bat (None, 64, 64, 304)  1216        decoder_conv0_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 64, 64, 304)  0           decoder_conv0_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise (Conv2D (None, 64, 64, 256)  77824       activation_77[0][0]
# __________________________________________________________________________________________________
# decoder_conv0_pointwise_BN (Bat (None, 64, 64, 256)  1024        decoder_conv0_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 64, 64, 256)  0           decoder_conv0_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise (Depthw (None, 64, 64, 256)  2304        activation_78[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_depthwise_BN (Bat (None, 64, 64, 256)  1024        decoder_conv1_depthwise[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 64, 64, 256)  0           decoder_conv1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise (Conv2D (None, 64, 64, 256)  65536       activation_79[0][0]
# __________________________________________________________________________________________________
# decoder_conv1_pointwise_BN (Bat (None, 64, 64, 256)  1024        decoder_conv1_pointwise[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 64, 64, 256)  0           decoder_conv1_pointwise_BN[0][0]
# __________________________________________________________________________________________________
# custom_logits_semantic (Conv2D) (None, 64, 64, 1)    257         activation_80[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 256, 256, 1)  0           custom_logits_semantic[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 256, 256, 1)  0           lambda_4[0][0]
# ==================================================================================================
# Total params: 41,253,073
# Trainable params: 41,050,273
# Non-trainable params: 202,800
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-deeplabv3+_best.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss="binary_crossentropy", metrics=["accuracy", dice_coef, f1])
results=model.fit(X_train, y_train, batch_size=8, epochs=50,
                    validation_data=(X_valid, y_valid), callbacks=callbacks)
# Out:
# Epoch 1/50
# 122/122 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.8414 - dice_coef: 0.6085 - f1: 0.6863
# Epoch 00001: val_loss improved from inf to 0.58693, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 467ms/step - loss: 0.3479 - accuracy: 0.8414 - dice_coef: 0.6085 - f1: 0.6863 - val_loss: 0.5869 - val_accuracy: 0.7240 - val_dice_coef: 0.2704 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 2/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.8775 - dice_coef: 0.6848 - f1: 0.7701
# Epoch 00002: val_loss did not improve from 0.58693
# 122/122 [==============================] - 55s 452ms/step - loss: 0.2791 - accuracy: 0.8775 - dice_coef: 0.6848 - f1: 0.7701 - val_loss: 0.5963 - val_accuracy: 0.7240 - val_dice_coef: 0.2376 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 3/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.8853 - dice_coef: 0.7016 - f1: 0.7860
# Epoch 00003: val_loss did not improve from 0.58693
# 122/122 [==============================] - 56s 459ms/step - loss: 0.2641 - accuracy: 0.8853 - dice_coef: 0.7016 - f1: 0.7860 - val_loss: 0.6017 - val_accuracy: 0.7240 - val_dice_coef: 0.2156 - val_f1: 0.0000e+00 - lr: 0.0010
# Epoch 4/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.8922 - dice_coef: 0.7182 - f1: 0.7989
# Epoch 00004: val_loss improved from 0.58693 to 0.43340, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 58s 473ms/step - loss: 0.2494 - accuracy: 0.8922 - dice_coef: 0.7182 - f1: 0.7989 - val_loss: 0.4334 - val_accuracy: 0.8152 - val_dice_coef: 0.4634 - val_f1: 0.5861 - lr: 0.0010
# Epoch 5/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.8977 - dice_coef: 0.7313 - f1: 0.8090
# Epoch 00005: val_loss did not improve from 0.43340
# 122/122 [==============================] - 56s 461ms/step - loss: 0.2387 - accuracy: 0.8977 - dice_coef: 0.7313 - f1: 0.8090 - val_loss: 0.7160 - val_accuracy: 0.5894 - val_dice_coef: 0.5321 - val_f1: 0.5661 - lr: 0.0010
# Epoch 6/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.8999 - dice_coef: 0.7377 - f1: 0.8135
# Epoch 00006: val_loss improved from 0.43340 to 0.26666, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.2326 - accuracy: 0.8999 - dice_coef: 0.7377 - f1: 0.8135 - val_loss: 0.2667 - val_accuracy: 0.8822 - val_dice_coef: 0.7192 - val_f1: 0.8061 - lr: 0.0010
# Epoch 7/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9052 - dice_coef: 0.7506 - f1: 0.8236
# Epoch 00007: val_loss improved from 0.26666 to 0.25534, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.2212 - accuracy: 0.9052 - dice_coef: 0.7506 - f1: 0.8236 - val_loss: 0.2553 - val_accuracy: 0.8882 - val_dice_coef: 0.7364 - val_f1: 0.8005 - lr: 0.0010
# Epoch 8/50
# 122/122 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9106 - dice_coef: 0.7639 - f1: 0.8337
# Epoch 00008: val_loss improved from 0.25534 to 0.22884, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.2093 - accuracy: 0.9106 - dice_coef: 0.7639 - f1: 0.8337 - val_loss: 0.2288 - val_accuracy: 0.9010 - val_dice_coef: 0.7472 - val_f1: 0.8053 - lr: 0.0010
# Epoch 9/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9175 - dice_coef: 0.7824 - f1: 0.8469
# Epoch 00009: val_loss did not improve from 0.22884
# 122/122 [==============================] - 56s 460ms/step - loss: 0.1931 - accuracy: 0.9175 - dice_coef: 0.7824 - f1: 0.8469 - val_loss: 0.3789 - val_accuracy: 0.8590 - val_dice_coef: 0.6517 - val_f1: 0.6795 - lr: 0.0010
# Epoch 10/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9222 - dice_coef: 0.7946 - f1: 0.8558
# Epoch 00010: val_loss improved from 0.22884 to 0.20781, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.1820 - accuracy: 0.9222 - dice_coef: 0.7946 - f1: 0.8558 - val_loss: 0.2078 - val_accuracy: 0.9105 - val_dice_coef: 0.7775 - val_f1: 0.8366 - lr: 0.0010
# Epoch 11/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9276 - dice_coef: 0.8082 - f1: 0.8655
# Epoch 00011: val_loss did not improve from 0.20781
# 122/122 [==============================] - 56s 463ms/step - loss: 0.1696 - accuracy: 0.9276 - dice_coef: 0.8082 - f1: 0.8655 - val_loss: 0.2713 - val_accuracy: 0.8901 - val_dice_coef: 0.7331 - val_f1: 0.7691 - lr: 0.0010
# Epoch 12/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9313 - dice_coef: 0.8188 - f1: 0.8731
# Epoch 00012: val_loss improved from 0.20781 to 0.18317, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.1613 - accuracy: 0.9313 - dice_coef: 0.8188 - f1: 0.8731 - val_loss: 0.1832 - val_accuracy: 0.9214 - val_dice_coef: 0.8021 - val_f1: 0.8519 - lr: 0.0010
# Epoch 13/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.9363 - dice_coef: 0.8314 - f1: 0.8821
# Epoch 00013: val_loss did not improve from 0.18317
# 122/122 [==============================] - 56s 462ms/step - loss: 0.1494 - accuracy: 0.9363 - dice_coef: 0.8314 - f1: 0.8821 - val_loss: 0.1917 - val_accuracy: 0.9199 - val_dice_coef: 0.8041 - val_f1: 0.8447 - lr: 0.0010
# Epoch 14/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9400 - dice_coef: 0.8416 - f1: 0.8893
# Epoch 00014: val_loss did not improve from 0.18317
# 122/122 [==============================] - 57s 463ms/step - loss: 0.1408 - accuracy: 0.9400 - dice_coef: 0.8416 - f1: 0.8893 - val_loss: 0.1902 - val_accuracy: 0.9221 - val_dice_coef: 0.8184 - val_f1: 0.8542 - lr: 0.0010
# Epoch 15/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9425 - dice_coef: 0.8485 - f1: 0.8940
# Epoch 00015: val_loss improved from 0.18317 to 0.16768, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.1352 - accuracy: 0.9425 - dice_coef: 0.8485 - f1: 0.8940 - val_loss: 0.1677 - val_accuracy: 0.9290 - val_dice_coef: 0.8281 - val_f1: 0.8689 - lr: 0.0010
# Epoch 16/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9446 - dice_coef: 0.8532 - f1: 0.8979
# Epoch 00016: val_loss did not improve from 0.16768
# 122/122 [==============================] - 56s 462ms/step - loss: 0.1302 - accuracy: 0.9446 - dice_coef: 0.8532 - f1: 0.8979 - val_loss: 0.1682 - val_accuracy: 0.9286 - val_dice_coef: 0.8276 - val_f1: 0.8625 - lr: 0.0010
# Epoch 17/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9485 - dice_coef: 0.8635 - f1: 0.9050
# Epoch 00017: val_loss did not improve from 0.16768
# 122/122 [==============================] - 56s 462ms/step - loss: 0.1207 - accuracy: 0.9485 - dice_coef: 0.8635 - f1: 0.9050 - val_loss: 0.1712 - val_accuracy: 0.9298 - val_dice_coef: 0.8313 - val_f1: 0.8659 - lr: 0.0010
# Epoch 18/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9509 - dice_coef: 0.8703 - f1: 0.9096
# Epoch 00018: val_loss improved from 0.16768 to 0.16104, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 466ms/step - loss: 0.1154 - accuracy: 0.9509 - dice_coef: 0.8703 - f1: 0.9096 - val_loss: 0.1610 - val_accuracy: 0.9318 - val_dice_coef: 0.8350 - val_f1: 0.8702 - lr: 0.0010
# Epoch 19/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9518 - dice_coef: 0.8727 - f1: 0.9112
# Epoch 00019: val_loss improved from 0.16104 to 0.16073, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 470ms/step - loss: 0.1133 - accuracy: 0.9518 - dice_coef: 0.8727 - f1: 0.9112 - val_loss: 0.1607 - val_accuracy: 0.9331 - val_dice_coef: 0.8377 - val_f1: 0.8736 - lr: 0.0010
# Epoch 20/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9545 - dice_coef: 0.8793 - f1: 0.9162
# Epoch 00020: val_loss improved from 0.16073 to 0.14485, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.1070 - accuracy: 0.9545 - dice_coef: 0.8793 - f1: 0.9162 - val_loss: 0.1448 - val_accuracy: 0.9390 - val_dice_coef: 0.8539 - val_f1: 0.8867 - lr: 0.0010
# Epoch 21/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9564 - dice_coef: 0.8848 - f1: 0.9197
# Epoch 00021: val_loss improved from 0.14485 to 0.14028, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.1022 - accuracy: 0.9564 - dice_coef: 0.8848 - f1: 0.9197 - val_loss: 0.1403 - val_accuracy: 0.9411 - val_dice_coef: 0.8582 - val_f1: 0.8906 - lr: 0.0010
# Epoch 22/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9582 - dice_coef: 0.8892 - f1: 0.9231
# Epoch 00022: val_loss improved from 0.14028 to 0.13130, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 58s 478ms/step - loss: 0.0982 - accuracy: 0.9582 - dice_coef: 0.8892 - f1: 0.9231 - val_loss: 0.1313 - val_accuracy: 0.9451 - val_dice_coef: 0.8675 - val_f1: 0.8983 - lr: 0.0010
# Epoch 23/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9588 - dice_coef: 0.8917 - f1: 0.9244
# Epoch 00023: val_loss did not improve from 0.13130
# 122/122 [==============================] - 56s 459ms/step - loss: 0.0964 - accuracy: 0.9588 - dice_coef: 0.8917 - f1: 0.9244 - val_loss: 0.1351 - val_accuracy: 0.9448 - val_dice_coef: 0.8711 - val_f1: 0.8981 - lr: 0.0010
# Epoch 24/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9612 - dice_coef: 0.8975 - f1: 0.9286
# Epoch 00024: val_loss improved from 0.13130 to 0.12682, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 467ms/step - loss: 0.0909 - accuracy: 0.9612 - dice_coef: 0.8975 - f1: 0.9286 - val_loss: 0.1268 - val_accuracy: 0.9472 - val_dice_coef: 0.8746 - val_f1: 0.9029 - lr: 0.0010
# Epoch 25/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9620 - dice_coef: 0.8997 - f1: 0.9300
# Epoch 00025: val_loss did not improve from 0.12682
# 122/122 [==============================] - 56s 461ms/step - loss: 0.0889 - accuracy: 0.9620 - dice_coef: 0.8997 - f1: 0.9300 - val_loss: 0.1286 - val_accuracy: 0.9480 - val_dice_coef: 0.8787 - val_f1: 0.9039 - lr: 0.0010
# Epoch 26/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9627 - dice_coef: 0.9015 - f1: 0.9313
# Epoch 00026: val_loss did not improve from 0.12682
# 122/122 [==============================] - 56s 463ms/step - loss: 0.0873 - accuracy: 0.9627 - dice_coef: 0.9015 - f1: 0.9313 - val_loss: 0.1546 - val_accuracy: 0.9415 - val_dice_coef: 0.8668 - val_f1: 0.8880 - lr: 0.0010
# Epoch 27/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9628 - dice_coef: 0.9020 - f1: 0.9316
# Epoch 00027: val_loss did not improve from 0.12682
# 122/122 [==============================] - 56s 462ms/step - loss: 0.0870 - accuracy: 0.9628 - dice_coef: 0.9020 - f1: 0.9316 - val_loss: 0.1450 - val_accuracy: 0.9431 - val_dice_coef: 0.8716 - val_f1: 0.8929 - lr: 0.0010
# Epoch 28/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9642 - dice_coef: 0.9057 - f1: 0.9343
# Epoch 00028: val_loss improved from 0.12682 to 0.12324, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.0839 - accuracy: 0.9642 - dice_coef: 0.9057 - f1: 0.9343 - val_loss: 0.1232 - val_accuracy: 0.9505 - val_dice_coef: 0.8884 - val_f1: 0.9116 - lr: 0.0010
# Epoch 29/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9656 - dice_coef: 0.9090 - f1: 0.9368
# Epoch 00029: val_loss improved from 0.12324 to 0.12216, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.0806 - accuracy: 0.9656 - dice_coef: 0.9090 - f1: 0.9368 - val_loss: 0.1222 - val_accuracy: 0.9509 - val_dice_coef: 0.8867 - val_f1: 0.9092 - lr: 0.0010
# Epoch 30/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9667 - dice_coef: 0.9120 - f1: 0.9388
# Epoch 00030: val_loss improved from 0.12216 to 0.11474, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 469ms/step - loss: 0.0779 - accuracy: 0.9667 - dice_coef: 0.9120 - f1: 0.9388 - val_loss: 0.1147 - val_accuracy: 0.9541 - val_dice_coef: 0.8947 - val_f1: 0.9167 - lr: 0.0010
# Epoch 31/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9680 - dice_coef: 0.9157 - f1: 0.9413
# Epoch 00031: val_loss did not improve from 0.11474
# 122/122 [==============================] - 56s 461ms/step - loss: 0.0748 - accuracy: 0.9680 - dice_coef: 0.9157 - f1: 0.9413 - val_loss: 0.1293 - val_accuracy: 0.9495 - val_dice_coef: 0.8863 - val_f1: 0.9052 - lr: 0.0010
# Epoch 32/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9685 - dice_coef: 0.9170 - f1: 0.9423
# Epoch 00032: val_loss did not improve from 0.11474
# 122/122 [==============================] - 56s 462ms/step - loss: 0.0736 - accuracy: 0.9685 - dice_coef: 0.9170 - f1: 0.9423 - val_loss: 0.1287 - val_accuracy: 0.9506 - val_dice_coef: 0.8897 - val_f1: 0.9090 - lr: 0.0010
# Epoch 33/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9684 - dice_coef: 0.9170 - f1: 0.9421
# Epoch 00033: val_loss did not improve from 0.11474
# 122/122 [==============================] - 56s 460ms/step - loss: 0.0738 - accuracy: 0.9684 - dice_coef: 0.9170 - f1: 0.9421 - val_loss: 0.1152 - val_accuracy: 0.9540 - val_dice_coef: 0.8950 - val_f1: 0.9164 - lr: 0.0010
# Epoch 34/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9689 - dice_coef: 0.9182 - f1: 0.9430
# Epoch 00034: val_loss did not improve from 0.11474
# 122/122 [==============================] - 57s 467ms/step - loss: 0.0726 - accuracy: 0.9689 - dice_coef: 0.9182 - f1: 0.9430 - val_loss: 0.1218 - val_accuracy: 0.9528 - val_dice_coef: 0.8960 - val_f1: 0.9146 - lr: 0.0010
# Epoch 35/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9702 - dice_coef: 0.9215 - f1: 0.9453
# Epoch 00035: val_loss improved from 0.11474 to 0.11290, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 467ms/step - loss: 0.0693 - accuracy: 0.9702 - dice_coef: 0.9215 - f1: 0.9453 - val_loss: 0.1129 - val_accuracy: 0.9564 - val_dice_coef: 0.9032 - val_f1: 0.9213 - lr: 0.0010
# Epoch 36/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9702 - dice_coef: 0.9215 - f1: 0.9451
# Epoch 00036: val_loss did not improve from 0.11290
# 122/122 [==============================] - 56s 462ms/step - loss: 0.0697 - accuracy: 0.9702 - dice_coef: 0.9215 - f1: 0.9451 - val_loss: 0.1151 - val_accuracy: 0.9557 - val_dice_coef: 0.9021 - val_f1: 0.9208 - lr: 0.0010
# Epoch 37/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9694 - dice_coef: 0.9197 - f1: 0.9438
# Epoch 00037: val_loss did not improve from 0.11290
# 122/122 [==============================] - 57s 464ms/step - loss: 0.0714 - accuracy: 0.9694 - dice_coef: 0.9197 - f1: 0.9438 - val_loss: 0.1201 - val_accuracy: 0.9526 - val_dice_coef: 0.8942 - val_f1: 0.9132 - lr: 0.0010
# Epoch 38/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9684 - dice_coef: 0.9174 - f1: 0.9419
# Epoch 00038: val_loss did not improve from 0.11290
# 122/122 [==============================] - 56s 461ms/step - loss: 0.0741 - accuracy: 0.9684 - dice_coef: 0.9174 - f1: 0.9419 - val_loss: 0.1458 - val_accuracy: 0.9462 - val_dice_coef: 0.8878 - val_f1: 0.9050 - lr: 0.0010
# Epoch 39/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9597 - dice_coef: 0.8953 - f1: 0.9255
# Epoch 00039: val_loss did not improve from 0.11290
# 122/122 [==============================] - 56s 460ms/step - loss: 0.0956 - accuracy: 0.9597 - dice_coef: 0.8953 - f1: 0.9255 - val_loss: 0.7666 - val_accuracy: 0.8337 - val_dice_coef: 0.5871 - val_f1: 0.5912 - lr: 0.0010
# Epoch 40/50
# 122/122 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9499 - dice_coef: 0.8682 - f1: 0.9072
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00040: val_loss did not improve from 0.11290
# 122/122 [==============================] - 56s 459ms/step - loss: 0.1187 - accuracy: 0.9499 - dice_coef: 0.8682 - f1: 0.9072 - val_loss: 0.9779 - val_accuracy: 0.8133 - val_dice_coef: 0.5161 - val_f1: 0.5132 - lr: 0.0010
# Epoch 41/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9626 - dice_coef: 0.8962 - f1: 0.9314
# Epoch 00041: val_loss did not improve from 0.11290
# 122/122 [==============================] - 56s 461ms/step - loss: 0.0885 - accuracy: 0.9626 - dice_coef: 0.8962 - f1: 0.9314 - val_loss: 0.1194 - val_accuracy: 0.9506 - val_dice_coef: 0.8829 - val_f1: 0.9102 - lr: 1.0000e-04
# Epoch 42/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9680 - dice_coef: 0.9115 - f1: 0.9413
# Epoch 00042: val_loss improved from 0.11290 to 0.11089, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 467ms/step - loss: 0.0753 - accuracy: 0.9680 - dice_coef: 0.9115 - f1: 0.9413 - val_loss: 0.1109 - val_accuracy: 0.9542 - val_dice_coef: 0.8915 - val_f1: 0.9178 - lr: 1.0000e-04
# Epoch 43/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9708 - dice_coef: 0.9193 - f1: 0.9464
# Epoch 00043: val_loss improved from 0.11089 to 0.11002, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.0688 - accuracy: 0.9708 - dice_coef: 0.9193 - f1: 0.9464 - val_loss: 0.1100 - val_accuracy: 0.9554 - val_dice_coef: 0.8973 - val_f1: 0.9208 - lr: 1.0000e-04
# Epoch 44/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9724 - dice_coef: 0.9241 - f1: 0.9494
# Epoch 00044: val_loss improved from 0.11002 to 0.10929, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.0648 - accuracy: 0.9724 - dice_coef: 0.9241 - f1: 0.9494 - val_loss: 0.1093 - val_accuracy: 0.9561 - val_dice_coef: 0.9005 - val_f1: 0.9221 - lr: 1.0000e-04
# Epoch 45/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9737 - dice_coef: 0.9277 - f1: 0.9517
# Epoch 00045: val_loss improved from 0.10929 to 0.10780, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 468ms/step - loss: 0.0621 - accuracy: 0.9737 - dice_coef: 0.9277 - f1: 0.9517 - val_loss: 0.1078 - val_accuracy: 0.9572 - val_dice_coef: 0.9033 - val_f1: 0.9234 - lr: 1.0000e-04
# Epoch 46/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9748 - dice_coef: 0.9307 - f1: 0.9539
# Epoch 00046: val_loss did not improve from 0.10780
# 122/122 [==============================] - 56s 462ms/step - loss: 0.0592 - accuracy: 0.9748 - dice_coef: 0.9307 - f1: 0.9539 - val_loss: 0.1080 - val_accuracy: 0.9577 - val_dice_coef: 0.9062 - val_f1: 0.9249 - lr: 1.0000e-04
# Epoch 47/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9757 - dice_coef: 0.9331 - f1: 0.9555
# Epoch 00047: val_loss did not improve from 0.10780
# 122/122 [==============================] - 56s 462ms/step - loss: 0.0572 - accuracy: 0.9757 - dice_coef: 0.9331 - f1: 0.9555 - val_loss: 0.1080 - val_accuracy: 0.9581 - val_dice_coef: 0.9079 - val_f1: 0.9257 - lr: 1.0000e-04
# Epoch 48/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9764 - dice_coef: 0.9354 - f1: 0.9568
# Epoch 00048: val_loss improved from 0.10780 to 0.10765, saving model to model-deeplabv3+_best.h5
# 122/122 [==============================] - 57s 467ms/step - loss: 0.0554 - accuracy: 0.9764 - dice_coef: 0.9354 - f1: 0.9568 - val_loss: 0.1076 - val_accuracy: 0.9586 - val_dice_coef: 0.9094 - val_f1: 0.9264 - lr: 1.0000e-04
# Epoch 49/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9769 - dice_coef: 0.9367 - f1: 0.9577
# Epoch 00049: val_loss did not improve from 0.10765
# 122/122 [==============================] - 56s 460ms/step - loss: 0.0543 - accuracy: 0.9769 - dice_coef: 0.9367 - f1: 0.9577 - val_loss: 0.1076 - val_accuracy: 0.9590 - val_dice_coef: 0.9107 - val_f1: 0.9269 - lr: 1.0000e-04
# Epoch 50/50
# 122/122 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9776 - dice_coef: 0.9386 - f1: 0.9591
# Epoch 00050: val_loss did not improve from 0.10765
# 122/122 [==============================] - 57s 466ms/step - loss: 0.0525 - accuracy: 0.9776 - dice_coef: 0.9386 - f1: 0.9591 - val_loss: 0.1086 - val_accuracy: 0.9591 - val_dice_coef: 0.9119 - val_f1: 0.9273 - lr: 1.0000e-04

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
X_test, y_test = get_images("ModMonuSeg/Test/", (im_width, im_height), gt_extension='png')
# Out:
# No. of images =  504
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(IntProgress(value=0, max=504), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py:104: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 16/16 [==============================] - 9s 579ms/step - loss: 0.3735 - accuracy: 0.9063 - dice_coef: 0.7696 - f1: 0.7802
# [0.3735491931438446, 0.906338632106781, 0.769550085067749, 0.7801830172538757]

# %%
# Predict on train, val and test
preds = model.predict(X_test, verbose=1)
preds_t = (preds > 0.5).astype(np.uint8)
# Out:
# 16/16 [==============================] - 8s 480ms/step

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Input')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Ground Truth')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Predicted')
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Predicted binary');

# %%
# Check if training data looks all right
plot_sample(X_test, y_test, preds, preds_t)
